# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bigmart_data.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (4650, 12)

# %% [markdown]
# # create a line chart to denote the mean price per item.  (plot for top 10 items)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df.groupby('Item_Type')['Item_MRP'].mean().sort_values(ascending=False).head().plot()
# Out:
# <Axes: xlabel='Item_Type'>

# %% [markdown]
# # What is the mean sales for each outlet type? (both bar chart, pie chart )

# %%
df.groupby('Outlet_Type')['Item_Outlet_Sales'].mean().plot.bar()
# Out:
# <Axes: xlabel='Outlet_Type'>

# %%
df.groupby('Outlet_Type')['Item_Outlet_Sales'].mean().plot.pie(autopct='%.1f%%') # formate (%.1f%%) 1 means how may decemal poitns
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # Histogram of Item_MRP

# %%
plt.hist(df['Item_MRP'],bins=20,)
# Out:
# (array([247., 249., 208.,  94., 261., 329., 337., 343., 164., 279., 304.,
#         276., 339., 318., 113., 143., 171., 145., 148., 182.]),
#  array([ 31.49   ,  43.25992,  55.02984,  66.79976,  78.56968,  90.3396 ,
#         102.10952, 113.87944, 125.64936, 137.41928, 149.1892 , 160.95912,
#         172.72904, 184.49896, 196.26888, 208.0388 , 219.80872, 231.57864,
#         243.34856, 255.11848, 266.8884 ]),
#  <BarContainer object of 20 artists>)

# %%
sns. histplot(df['Item_MRP'],bins=20)
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Count'>

# %% [markdown]
# # Box plot of item weight

# %%
sns.boxplot(df['Item_Weight'])
# Out:
# <Axes: ylabel='Item_Weight'>

# %%
sns.boxplot(df[['Item_Weight','Item_MRP']])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# # Relative distribution of item weight and its visibility(scatter plot)

# %%
import seaborn as sns

sns.scatterplot(x=df['Item_Weight'], y=df['Item_Visibility'])
plt.title("Scatter Plot of Item Weight vs Item Visibility")
plt.show()

# %% [markdown]
# # Violin plot for Item_Outlet_Sales

# %%
sns.violinplot(df['Item_Outlet_Sales'])
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # sctter plot using seaborn add hue

# %%
df5 = df[['Item_Weight','Item_MRP','Item_Outlet_Sales','Outlet_Type']]

sns.violinplot(x='Outlet_Type', y='Item_Outlet_Sales', hue='Outlet_Type', data=df5, split=False)
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # heat map for selected numeric columns

# %%
num_cols = ['Item_Weight','Item_MRP','Item_Outlet_Sales']

corr = df[num_cols].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
# Out:
# <Axes: >
